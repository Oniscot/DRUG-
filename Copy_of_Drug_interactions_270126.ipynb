# %%
import numpy as np

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive/',force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir "/content/gdrive/MyDrive/colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/colab Notebooks/data’: No such file or directory

# %%
import os
# List contents of MyDrive to check for 'colab Notebooks'
print(os.listdir('/content/gdrive/MyDrive'))
# Out:
# ['Colab Notebooks', 'hcsw-induction-checklist-and-resources.docx', '15092023_RESULTS AND DISCUSSIONS_THESIS2 - Copy.docx', 'CV_ONILUDE_HYDROGEL_POLYMERS.pdf', 'CV_Onilude_112125_3.pdf']

# %%
pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target

# %%
target_query=target.search('BRCA2')

# %%
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism                              pref_name  \
# 0               []  Homo sapiens  Lys-63-specific deubiquitinase BRCC36
# 1               []  Homo sapiens   BRCA2 and CDKN1A-interacting protein
#
#    score  species_group_flag target_chembl_id  \
# 0   18.0               False    CHEMBL4105965
# 1   16.0               False    CHEMBL6067087
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P46736', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'Q9P287', 'component_descriptio...  SINGLE PROTEIN    9606

# %%
selected_target=targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL4105965'

# %%
activity=new_client.activity

# %%
results=activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1=pd.DataFrame.from_dict(results)

# %%
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None           Active     18229160                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL4049715  Inhibition of BRCC36 (unknown origin) using Di...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000201  ...
#
#   target_organism                       target_pref_name target_tax_id  \
# 0    Homo sapiens  Lys-63-specific deubiquitinase BRCC36          9606
#
#   text_value  toid type units    uo_units upper_value value
# 0       None  None  INH  None  UO_0000187        None  None
#
# [1 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['Inhibition'], dtype=object)

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %%
# !cp bioactivity_raw_data.csv "/content/gdrive/MyDrive/colab Notebooks/data"
# Out:
# cp: failed to access '/content/gdrive/MyDrive/colab Notebooks/data': Transport endpoint is not connected

# %%
import shutil

# %%
import os

# %%
source = "bioactivity_raw_data.csv"
destination_folder = "/content/drive/MyDrive/colab Notebooks/data"

# %%
os.makedirs(destination_folder, exist_ok=True)

# %%
shutil.copy(source, destination_folder)
# Out:
# '/content/drive/MyDrive/colab Notebooks/data/bioactivity_raw_data.csv'

# %%
print("File copied successfully!")
# Out:
# File copied successfully!

# %%
# !fusermount -u /content/gdrive 2> /dev/null

# %%
# !fusermount -u /content/drive  2> /dev/null

# %%
# !cp bioactivity_raw_data.csv"/content/gdrive/My Drive/Colab/Notebooks/bioactivity/data"
# Out:
# cp: missing destination file operand after 'bioactivity_raw_data.csv/content/gdrive/My Drive/Colab/Notebooks/bioactivity/data'
# Try 'cp --help' for more information.
